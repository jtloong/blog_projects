# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

# %%
data = pd.read_csv('elementary_data.csv')

# %%
data.head()
# Out:
#   board_id  board_name  school_id                            school_name  \
# 0   B28010  Algoma DSB      19186              Anna McCrea Public School
# 1   B28010  Algoma DSB      67679         Arthur Henderson Public School
# 2   B28010  Algoma DSB      43362           Ben R McMullin Public School
# 3   B28010  Algoma DSB      54542              Blind River Public School
# 4   B28010  Algoma DSB     490822  Boreal French Immersion Public School
#
#        municipality enrolment       lat      long first_lang_not_english  \
# 0  Sault Ste. Marie      168   46.50593 -84.28732                     SP
# 1       Bruce Mines      101   46.30183 -83.78020                     SP
# 2  Sault Ste. Marie      189   46.52455 -84.29804                     SP
# 3       Blind River      187   46.18454 -82.95760                     SP
# 4  Sault Ste. Marie      392   46.52447 -84.31073                     SP
#
#   first_lang_not_french          ...          special_ed gifted  \
# ...

# %%
# Out:
# str
