# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

# %%
data = pd.read_csv('elementary_data.csv')

# %%
data.head()
# Out:
#   Board Number  Board Name  School Number  \
# 0       B28010  Algoma DSB          19186
# 1       B28010  Algoma DSB          67679
# 2       B28010  Algoma DSB          43362
# 3       B28010  Algoma DSB          54542
# 4       B28010  Algoma DSB         490822
#
#                              School Name      Municipality Enrolment  \
# 0              Anna McCrea Public School  Sault Ste. Marie      168
# 1         Arthur Henderson Public School       Bruce Mines      101
# 2           Ben R McMullin Public School  Sault Ste. Marie      189
# 3              Blind River Public School       Blind River      187
# 4  Boreal French Immersion Public School  Sault Ste. Marie      392
#
#    Latitude  Longitude  \
# 0  46.50593  -84.28732
# 1  46.30183  -83.78020
# 2  46.52455  -84.29804
# 3  46.18454  -82.95760
# 4  46.52447  -84.31073
#
#   Percentage of Students Whose First Language Is Not English  \
# 0                                                 SP
# ...
