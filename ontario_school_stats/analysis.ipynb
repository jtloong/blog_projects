# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('elementary_data.csv')

# %%
data.head()
# Out:
#   board_id  board_name  school_id                            school_name  \
# 0   B28010  Algoma DSB      19186              Anna McCrea Public School
# 1   B28010  Algoma DSB      67679         Arthur Henderson Public School
# 2   B28010  Algoma DSB      43362           Ben R McMullin Public School
# 3   B28010  Algoma DSB      54542              Blind River Public School
# 4   B28010  Algoma DSB     490822  Boreal French Immersion Public School
#
#        municipality  enrolment       lat      long  first_lang_not_english  \
# 0  Sault Ste. Marie      168.0  46.50593 -84.28732                     NaN
# 1       Bruce Mines      101.0  46.30183 -83.78020                     NaN
# 2  Sault Ste. Marie      189.0  46.52455 -84.29804                     NaN
# 3       Blind River      187.0  46.18454 -82.95760                     NaN
# 4  Sault Ste. Marie      392.0  46.52447 -84.31073                     NaN
#
#    first_lang_not_french          ...            special_ed  gifted  \
# ...

# %%
data.describe()
# Out:
#            school_id    enrolment          lat         long  \
# count    4011.000000  3907.000000  4011.000000  4011.000000
# mean   470598.244328   342.129511    44.216339   -79.722727
# std    270190.641903   187.494837     1.425874     2.595221
# min        78.000000    10.000000    41.806950   -94.562100
# 25%    226249.500000   202.000000    43.471980   -80.308555
# 50%    485322.000000   311.000000    43.771250   -79.566400
# 75%    737385.500000   455.000000    44.455425   -79.212140
# max    874396.000000   993.000000    51.466270   -74.471020
#
#        first_lang_not_english  first_lang_not_french     newcomer  \
# count             2655.000000            3880.000000  1341.000000
# mean                31.917439              95.457474     7.958091
# std                 24.101915              15.429466     5.758722
# min                  1.500000               3.900000     1.200000
# 25%                 10.850000              99.500000     4.000000
# ...

# %%
data_g6_writing = data.dropna()

# %%
data_g6_writing.describe()
# Out:
#            school_id   enrolment        lat       long  \
# count      83.000000   83.000000  83.000000  83.000000
# mean   425088.481928  570.361446  43.789134 -79.262606
# std    261244.794324  186.983407   0.522969   1.163228
# min     13200.000000  217.000000  42.997920 -81.312880
# 25%    251821.000000  410.500000  43.586390 -79.640345
# 50%    354716.000000  583.000000  43.684910 -79.431050
# 75%    692483.000000  727.500000  43.803895 -79.348555
# max    850071.000000  954.000000  45.406280 -75.620130
#
#        first_lang_not_english  first_lang_not_french   newcomer  special_ed  \
# count               83.000000              83.000000  83.000000   83.000000
# mean                34.020482              99.365060   5.977108   20.292771
# std                 20.508409               0.975734   4.211550   11.208966
# min                  6.000000              95.000000   1.500000    5.800000
# 25%                 17.900000              99.400000   3.000000   10.450000
# ...

# %%
list(data_g6_writing)
# Out:
# ['board_id',
#  'board_name',
#  'school_id',
#  'school_name',
#  'municipality',
#  'enrolment',
#  'lat',
#  'long',
#  'first_lang_not_english',
#  'first_lang_not_french',
#  'newcomer',
#  'special_ed',
#  'gifted',
#  'grade_3_standard_reading',
#  'grade_3_standard_writing',
#  'grade_3_standard_math',
#  'grade_6_standard_reading',
#  'grade_6_standard_writing',
#  'grade_6_standard_math',
#  'low_income',
#  'parent_university_edu']

# %%
data_g6_writing = data_g6_writing[['enrolment','first_lang_not_english',
 'first_lang_not_french',
 'newcomer',
 'special_ed',
 'gifted', 'grade_6_standard_writing','low_income',
 'parent_university_edu']]

# %% [markdown]
# # Random Forest Model

# %%
X_train, X_test, y_train, y_test = train_test_split(data_g6_writing.drop('grade_6_standard_writing',axis=1), 
                                                    data_g6_writing['grade_6_standard_writing'], test_size=0.30, 
                                                    random_state=101)

# %%
rfc = RandomForestClassifier(n_estimators=1000)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#              precision    recall  f1-score   support
#
#        72.0       0.00      0.00      0.00         0
#        76.0       0.00      0.00      0.00         0
#        79.0       0.00      0.00      0.00         0
#        81.0       0.00      0.00      0.00         1
#        82.0       0.00      0.00      0.00         2
#        83.0       0.00      0.00      0.00         0
#        85.0       0.00      0.00      0.00         1
#        87.0       0.00      0.00      0.00         3
#        88.0       0.00      0.00      0.00         2
#        89.0       0.00      0.00      0.00         1
#        90.0       0.00      0.00      0.00         2
#        91.0       0.00      0.00      0.00         0
#        92.0       0.00      0.00      0.00         2
#        93.0       0.00      0.00      0.00         2
#        94.0       0.00      0.00      0.00         1
#        95.0       0.00      0.00      0.00         3
#        96.0       0.00      0.00      0.00         3
# ...
