# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#   Board Number  Board Name              Board Type  School Number  \
# 0       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)         902344
# 1       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          19186
# 2       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          67679
# 3       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          43362
# 4       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          54542
#
#                                     School Name School Type  \
# 0  Algoma Education Connection Secondary School      Public
# 1                     Anna McCrea Public School      Public
# 2                Arthur Henderson Public School      Public
# 3                  Ben R McMullin Public School      Public
# 4                     Blind River Public School      Public
#
#   School Special Condition Code School Level School Language Grade Range  \
# 0                   Alternative    Secondary         English        9-12
# ...

# %%
data.describe()
# Out:
#        School Number     Latitude    Longitude  \
# count    4934.000000  4934.000000  4934.000000
# mean   545630.117146    44.240924   -79.717050
# std    291844.462579     1.451152     2.603641
# min        78.000000    41.806950   -94.563700
# 25%    282184.250000    43.477645   -80.312427
# 50%    595927.000000    43.774220   -79.564585
# 75%    798174.250000    44.552090   -79.212620
# max    968729.000000    51.466270   -74.471020
#
#        Change in Grade 3 Reading Achievement Over Three Years  \
# count                                        1233.000000
# mean                                            3.987835
# std                                            15.081242
# min                                           -61.000000
# 25%                                            -5.000000
# 50%                                             4.000000
# 75%                                            13.000000
# max                                            83.000000
#
# ...

# %%
data['School Level'].value_counts()
# Out:
# Elementary    4011
# Secondary      923
# Name: School Level, dtype: int64

# %% [markdown]
# # Exclude Secondary Schools

# %%
elementary = data[data['School Level'] == 'Elementary']

# %%
list(elementary)
# Out:
# ['Board Number',
#  'Board Name',
#  'Board Type',
#  'School Number',
#  'School Name',
#  'School Type',
#  'School Special Condition Code',
#  'School Level',
#  'School Language',
#  'Grade Range',
#  'Building Suite',
#  'P.O. Box',
#  'Street',
#  'Municipality',
#  'City',
#  'Province',
#  'Postal Code',
#  'Phone Number',
#  'Fax Number',
#  'School Website',
#  'Board Website',
#  'Enrolment',
#  'Latitude',
#  'Longitude',
#  'Percentage of Students Whose First Language Is Not English',
#  'Percentage of Students Whose First Language Is Not French',
#  'Percentage of Students Who Are New to Canada from a Non-English Speaking Country',
#  'Percentage of Students Who Are New to Canada from a Non-French Speaking Country',
#  'Percentage of Students Receiving Special Education Services',
#  'Percentage of Students Identified as Gifted',
#  'Percentage of Grade 3 Students Achieving the Provincial Standard in Reading',
# ...

# %%
elementary = elementary[['Board Number',
 'Board Name','School Number',
 'School Name','Municipality','Enrolment',
 'Latitude',
 'Longitude','Percentage of Students Whose First Language Is Not English',
 'Percentage of Students Whose First Language Is Not French',
 'Percentage of Students Who Are New to Canada from a Non-English Speaking Country','Percentage of Students Receiving Special Education Services',
 'Percentage of Students Identified as Gifted','Percentage of Grade 3 Students Achieving the Provincial Standard in Reading', 'Percentage of Grade 3 Students Achieving the Provincial Standard in Writing',
                         'Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics','Percentage of Grade 6 Students Achieving the Provincial Standard in Reading', 'Percentage of Grade 6 Students Achieving the Provincial Standard in Writing',
                         'Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics','Percentage of Children Who Live in Low-Income Households',
 'Percentage of Students Whose Parents Have Some Unviersity Education',]]

# %%
elementary.head()
# Out:
#   Board Number  Board Name  School Number  \
# 1       B28010  Algoma DSB          19186
# 2       B28010  Algoma DSB          67679
# 3       B28010  Algoma DSB          43362
# 4       B28010  Algoma DSB          54542
# 5       B28010  Algoma DSB         490822
#
#                              School Name      Municipality Enrolment  \
# 1              Anna McCrea Public School  Sault Ste. Marie      168
# 2         Arthur Henderson Public School       Bruce Mines      101
# 3           Ben R McMullin Public School  Sault Ste. Marie      189
# 4              Blind River Public School       Blind River      187
# 5  Boreal French Immersion Public School  Sault Ste. Marie      392
#
#    Latitude  Longitude  \
# 1  46.50593  -84.28732
# 2  46.30183  -83.78020
# 3  46.52455  -84.29804
# 4  46.18454  -82.95760
# 5  46.52447  -84.31073
#
#   Percentage of Students Whose First Language Is Not English  \
# 1                                                 SP
# ...

# %%
list(elementary)
# Out:
# ['Board Number',
#  'Board Name',
#  'School Number',
#  'School Name',
#  'Municipality',
#  'Enrolment',
#  'Latitude',
#  'Longitude',
#  'Percentage of Students Whose First Language Is Not English',
#  'Percentage of Students Whose First Language Is Not French',
#  'Percentage of Students Who Are New to Canada from a Non-English Speaking Country',
#  'Percentage of Students Receiving Special Education Services',
#  'Percentage of Students Identified as Gifted',
#  'Percentage of Grade 3 Students Achieving the Provincial Standard in Reading',
#  'Percentage of Grade 3 Students Achieving the Provincial Standard in Writing',
#  'Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics',
#  'Percentage of Grade 6 Students Achieving the Provincial Standard in Reading',
#  'Percentage of Grade 6 Students Achieving the Provincial Standard in Writing',
#  'Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics',
# ...

# %%
elementary.columns = ['board_id', 'board_name', 'school_id', 'school_name',
                     'municipality', 'enrolment', 'lat', 'long', 'first_lang_not_english',
                     'first_lang_not_french', 'newcomer', 'special_ed', 
                     'gifted', 'grade_3_standard_reading', 'grade_3_standard_writing',
                     'grade_3_standard_math', 'grade_6_standard_reading', 
                     'grade_6_standard_writing', 'grade_6_standard_math',
                     'low_income', 'parent_university_edu']

# %%
elementary.head()
# Out:
#   board_id  board_name  school_id                            school_name  \
# 1   B28010  Algoma DSB      19186              Anna McCrea Public School
# 2   B28010  Algoma DSB      67679         Arthur Henderson Public School
# 3   B28010  Algoma DSB      43362           Ben R McMullin Public School
# 4   B28010  Algoma DSB      54542              Blind River Public School
# 5   B28010  Algoma DSB     490822  Boreal French Immersion Public School
#
#        municipality enrolment       lat      long first_lang_not_english  \
# 1  Sault Ste. Marie      168   46.50593 -84.28732                     SP
# 2       Bruce Mines      101   46.30183 -83.78020                     SP
# 3  Sault Ste. Marie      189   46.52455 -84.29804                     SP
# 4       Blind River      187   46.18454 -82.95760                     SP
# 5  Sault Ste. Marie      392   46.52447 -84.31073                     SP
#
#   first_lang_not_french          ...          special_ed gifted  \
# ...

# %%
elementary.to_csv('elementary_data.csv', index=False)
